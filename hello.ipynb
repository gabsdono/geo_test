# %% [markdown]
# # Introduction to Jupyter Notebook
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/gabsdono/geo_test/blob/main/hello.ipynb#scrollTo=42919122)
#
# To run this notebook, you need to install leafmap:
#
# ```bash
# pip install leafmap
# ```

# %%
print("Hello world")
# Out:
# Hellor world

# %%
import os
os.getcwd()
# Out:
# 'c:\\Users\\Gabriela\\Desktop\\chamba\\geo_test'

# %%
# !pip install leafmap

# %%
import leafmap

# %%
m = leafmap.Map()
m
# Out:
# Map(center=[20, 0], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out_text…
